# %% [markdown]
# # Task 1

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading CSV file

# %%
df=pd.read_csv("P_Data_Extract_From_World_Development_Indicators.csv")

# %% [markdown]
# ## Checking top 5 rows data

# %%
df.head(5)
# Out:
#          Series Name  Series Code    Country Name Country Code        2001  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  20284307.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   3060173.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  31331221.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     57053.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     65852.0
#
#          2002        2003        2004        2005        2006  ...  \
# 0  21378117.0  22733049.0  23560654.0  24404567.0  25424094.0  ...
# 1   3051010.0   3039616.0   3026939.0   3011487.0   2992547.0  ...
# 2  31750835.0  32175818.0  32628286.0  33109249.0  33623506.0  ...
# 3     57062.0     56971.0     56818.0     56617.0     56374.0  ...
# 4     66506.0     69486.0     74325.0     77421.0     79585.0  ...
#
#          2014        2015        2016        2017        2018        2019  \
# ...

# %% [markdown]
# ## Checking data from bottom

# %%
df.tail(5)
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2001       2002       2003  \
# 1080  Virgin Islands (U.S.)          VIR  47.679819  47.705178  47.735530
# 1081     West Bank and Gaza          PSE  50.470748  50.373409  50.267196
# 1082            Yemen, Rep.          YEM  50.444452  50.467908  50.489859
# 1083                 Zambia          ZMB  48.421539  48.508234  48.588377
# 1084               Zimbabwe          ZWE  47.518911  47.494993  47.483004
#
#            2004       2005       2006  ...       2014       2015       2016  \
# ...

# %% [markdown]
# ## Checking the columns of the dataset

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023'],
#       dtype='object')

# %% [markdown]
# ## Some information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2001          1085 non-null   float64
#  5   2002          1085 non-null   float64
#  6   2003          1085 non-null   float64
#  7   2004          1085 non-null   float64
#  8   2005          1085 non-null   float64
#  9   2006          1085 non-null   float64
#  10  2007          1085 non-null   float64
#  11  2008          1085 non-null   float64
#  12  2009          1085 non-null   float64
#  13  2010          1085 non-null   float64
#  14  2011          1085 non-null   float64
#  15  2012          1085 non-null   float64
#  16  2013          1085 non-null   float64
# ...

# %%
df.describe()
# Out:
#                2001          2002          2003          2004          2005  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.147056e+07  1.162227e+07  1.177350e+07  1.192626e+07  1.207914e+07
# std    6.491592e+07  6.567114e+07  6.640158e+07  6.712752e+07  6.784358e+07
# min    3.101681e+01  3.101478e+01  3.101950e+01  3.102362e+01  3.102243e+01
# 25%    5.039600e+01  5.038981e+01  5.039789e+01  5.039095e+01  5.037062e+01
# 50%    1.146200e+05  1.167310e+05  1.187900e+05  1.207380e+05  1.224230e+05
# 75%    4.603866e+06  4.769465e+06  4.813185e+06  4.958093e+06  5.052257e+06
# max    1.271850e+09  1.280400e+09  1.288400e+09  1.296075e+09  1.303720e+09
#
#                2006          2007          2008          2009          2010  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.223395e+07  1.238946e+07  1.254773e+07  1.270612e+07  1.286183e+07
# ...

# %% [markdown]
# ## Checking for duplicates values

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1080    False
# 1081    False
# 1082    False
# 1083    False
# 1084    False
# Length: 1085, dtype: bool

# %% [markdown]
# ## Checking for missing values

# %%
df.isna()
# Out:
#       Series Name  Series Code  Country Name  Country Code   2001   2002  \
# 0           False        False         False         False  False  False
# 1           False        False         False         False  False  False
# 2           False        False         False         False  False  False
# 3           False        False         False         False  False  False
# 4           False        False         False         False  False  False
# ...           ...          ...           ...           ...    ...    ...
# 1080        False        False         False         False  False  False
# 1081        False        False         False         False  False  False
# 1082        False        False         False         False  False  False
# 1083        False        False         False         False  False  False
# 1084        False        False         False         False  False  False
#
#        2003   2004   2005   2006  ...   2014   2015   2016   2017   2018  \
# ...

# %% [markdown]
# ## Checking unique values for columns

# %%
print(df['Country Name'].unique())
print("\n Total no of unique countries:",df['Country Name'].nunique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
# ...

# %%
print(df['Country Code'].unique())
print("\n Total no of unique country code:",df['Country Code'].nunique())
# Out:
# ['AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT'
#  'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL'
#  'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN'
#  'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV'
#  'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV'
#  'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB'
#  'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY'
#  'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG' 'MWI'
#  'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG'
#  'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC' 'NER'
#  'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER' 'PHL'
# ...

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(['Series Name','Country Name'],axis=1,inplace=True)

# %% [markdown]
# ## Extarction of top 10 countries with respect to total population

# %%
# Filter data for total population
total_population_data = df[df['Series Code'] == 'SP.POP.TOTL']

# Sort data based on the total population for 2023
total_population_sorted = total_population_data.sort_values(by="2023", ascending=False)

# Get the top ten countries with the highest total population for 2023
total_top_ten_countries = total_population_sorted.head(10)
print("Top ten countries of total population\n")
print(total_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of total population
#
#     Country Code
# 89           IND
# 41           CHN
# 206          USA
# 90           IDN
# 149          PAK
# 144          NGA
# 26           BRA
# 15           BGD
# 161          RUS
# 127          MEX

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# ## Top ten countries of total population in year 2023 and 2017

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country Code", data=total_top_ten_countries, palette="coolwarm")
plt.title("Top Ten Countries of Total Population (2023)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2017", y="Country Code", data=total_top_ten_countries, palette="coolwarm")
plt.title("Top Ten Countries of Total Population (2017)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\shant\AppData\Local\Temp\ipykernel_15016\2234153744.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2023", y="Country Code", data=total_top_ten_countries, palette="coolwarm")
# C:\Users\shant\AppData\Local\Temp\ipykernel_15016\2234153744.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2017", y="Country Code", data=total_top_ten_countries, palette="coolwarm")

# %% [markdown]
# ## Extraction of bottom 10 countries with respect to total popultaion

# %%
# Sort data based on the total population for 2023
total_population_sorted1 = total_population_data.sort_values(by="2023", ascending=True)

# Get the top ten countries with the highest total population for 2023
total_bottom_ten_countries = total_population_sorted1.head(10)
print("Bottom ten countries of total population\n")
print(total_bottom_ten_countries[['Country Code']])
# Out:
# Bottom ten countries of total population
#
#     Country Code
# 201          TUV
# 137          NRU
# 150          PLW
# 183          MAF
# 164          SMR
# 75           GIB
# 124          MHL
# 130          MCO
# 27           VGB
# 114          LIE

# %% [markdown]
# ## Bottom ten countries of total population in year 2023 and 2017

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of Total Population (2023)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2017", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of Total Population (2017)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\shant\AppData\Local\Temp\ipykernel_15016\1973246323.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2023", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
# C:\Users\shant\AppData\Local\Temp\ipykernel_15016\1973246323.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2017", y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")

# %% [markdown]
# ## Extarction of top 10 countries with highest male population

# %%
#filter data for male population
male_population_data = df[df['Series Code']=='SP.POP.TOTL.MA.IN']

#sort data based on the male population for 2023
male_population_sorted =male_population_data.sort_values(by="2023",ascending=False)

#Get the top 10 countries with the highest male population for 2023
male_top_ten_countries = male_population_sorted .head(10)
print("Top ten countries of male population")
print(male_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of male population
#     Country Code
# 523          IND
# 475          CHN
# 640          USA
# 524          IDN
# 583          PAK
# 578          NGA
# 460          BRA
# 449          BGD
# 595          RUS
# 498          ETH

# %% [markdown]
# ## Extarction of top 10 countries with highest female population

# %%
#filter data for female population
female_population_data = df[df['Series Code']=='SP.POP.TOTL.FE.IN']

#sort data based on the female population for 2023
female_population_sorted =female_population_data.sort_values(by="2023",ascending=False)

#Get the top 10 countries with the highest female population for 2023
female_top_ten_countries = female_population_sorted .head(10)
print("Top ten countries of female population")
print(female_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of female population
#     Country Code
# 306          IND
# 258          CHN
# 423          USA
# 307          IDN
# 366          PAK
# 361          NGA
# 243          BRA
# 232          BGD
# 378          RUS
# 344          MEX

# %% [markdown]
# ## Top ten countries with highest male and female population in 2023

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country Code", data=male_top_ten_countries, palette="viridis")
plt.title("Top ten conuntries of male population(2023)",fontsize=10)
plt.xlabel("Male Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2017", y="Country Code", data=female_top_ten_countries, palette="viridis")
plt.title("Top ten conuntries of female population(2023)",fontsize=10)
plt.xlabel("Female Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\shant\AppData\Local\Temp\ipykernel_15016\2535165668.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2023", y="Country Code", data=male_top_ten_countries, palette="viridis")
# C:\Users\shant\AppData\Local\Temp\ipykernel_15016\2535165668.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2017", y="Country Code", data=female_top_ten_countries, palette="viridis")

# %% [markdown]
# ## Stacked Bar Plot

# %% [markdown]
# ## Top 10 countries with male and female population

# %%
#merge male and female population data on 'Country Code'
merge_data=pd.merge(male_population_data,female_population_data,on="Country Code",suffixes=("_male","_female"))

# %%
#merged data
#calculate the total population for each country (male + female)
merge_data["Total population"] = merge_data["2023_male"] + merge_data ["2023_female"]

# %%
merge_data.head()
# Out:
#     Series Code_male Country Code   2001_male   2002_male   2003_male  \
# 0  SP.POP.TOTL.MA.IN          AFG  10179793.0  10737198.0  11426685.0
# 1  SP.POP.TOTL.MA.IN          ALB   1491913.0   1489449.0   1486823.0
# 2  SP.POP.TOTL.MA.IN          DZA  16136100.0  16342428.0  16551159.0
# 3  SP.POP.TOTL.MA.IN          ASM     29227.0     29196.0     29122.0
# 4  SP.POP.TOTL.MA.IN          AND     34216.0     34483.0     36057.0
#
#     2004_male   2005_male   2006_male   2007_male   2008_male  ...  \
# 0  11851534.0  12284658.0  12805479.0  13056363.0  13350888.0  ...
# 1   1483416.0   1478462.0   1471577.0   1462729.0   1453666.0  ...
# 2  16774177.0  17011030.0  17264374.0  17545719.0  17861443.0  ...
# 3     29018.0     28890.0     28743.0     28590.0     28419.0  ...
# 4     38689.0     40374.0     41583.0     42851.0     43674.0  ...
#
#    2015_female  2016_female  2017_female  2018_female  2019_female  \
# 0   16732244.0   17159297.0   17649936.0   18178417.0   18736474.0
# ...

# %%
#sort data based on total population in descending order
sorted_data = merge_data.sort_values(by="Total population", ascending=False)

# %% [markdown]
# ## Select the top 10 countries with the highest total population

# %%
top_10_countries = sorted_data.head(10)

# %%
#create the staked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code",y="2023_female",data=top_10_countries,color="red",label="female Population")
sns.barplot(x="Country Code",y="2023_male",data=top_10_countries,bottom=top_10_countries["2023_female"],color="green",label="Male Population")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()

# %% [markdown]
# ## Bottom 10 countries with male and female population(2023)

# %%
bottom_10_countries = sorted_data.tail(10)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x="Country Code", y="2023_female", data=bottom_10_countries, color="red", label="Female Population")
sns.barplot(x="Country Code", y="2023_male", data=bottom_10_countries, bottom=bottom_10_countries["2023_female"], color="green", label="Male Population")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()
